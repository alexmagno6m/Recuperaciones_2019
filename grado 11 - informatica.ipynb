# %% [markdown]
# <h1>Tabla de contenido<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Recuperacion-General-de-Informatica---Grado-11" data-toc-modified-id="Recuperacion-General-de-Informatica---Grado-11-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Recuperacion General de Informatica - Grado 11</a></span><ul class="toc-item"><li><span><a href="#Instrucciones" data-toc-modified-id="Instrucciones-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Instrucciones</a></span></li><li><span><a href="#Nivelacion-Primer-Periodo" data-toc-modified-id="Nivelacion-Primer-Periodo-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Nivelacion Primer Periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-escrito" data-toc-modified-id="Trabajo-escrito-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Trabajo escrito</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Ejercicios</a></span></li></ul></li><li><span><a href="#Nivelacion-Segundo-Periodo" data-toc-modified-id="Nivelacion-Segundo-Periodo-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Nivelacion Segundo Periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-Escrito" data-toc-modified-id="Trabajo-Escrito-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Trabajo Escrito</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Ejercicios</a></span></li></ul></li><li><span><a href="#Nivelacion-tercer-periodo" data-toc-modified-id="Nivelacion-tercer-periodo-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Nivelacion tercer periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-escrito" data-toc-modified-id="Trabajo-escrito-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Trabajo escrito</a></span></li><li><span><a href="#Ejercicio-1" data-toc-modified-id="Ejercicio-1-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Ejercicio 1</a></span><ul class="toc-item"><li><span><a href="#Diseño-de-la-página" data-toc-modified-id="Diseño-de-la-página-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>Diseño de la página</a></span></li><li><span><a href="#Funcionamiento-del-Script" data-toc-modified-id="Funcionamiento-del-Script-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>Funcionamiento del Script</a></span></li></ul></li><li><span><a href="#Ejercicio-2" data-toc-modified-id="Ejercicio-2-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Ejercicio 2</a></span><ul class="toc-item"><li><span><a href="#Diseño-de-la-página" data-toc-modified-id="Diseño-de-la-página-1.4.3.1"><span class="toc-item-num">1.4.3.1&nbsp;&nbsp;</span>Diseño de la página</a></span></li><li><span><a href="#Funcionamiento-del-Script" data-toc-modified-id="Funcionamiento-del-Script-1.4.3.2"><span class="toc-item-num">1.4.3.2&nbsp;&nbsp;</span>Funcionamiento del Script</a></span></li></ul></li></ul></li><li><span><a href="#Nivelacion-cuarto-periodo" data-toc-modified-id="Nivelacion-cuarto-periodo-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Nivelacion cuarto periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-escrito" data-toc-modified-id="Trabajo-escrito-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Trabajo escrito</a></span></li><li><span><a href="#Ejercicio" data-toc-modified-id="Ejercicio-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Ejercicio</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Recuperacion General de Informatica - Grado 11
# ## Instrucciones
# > 1. Si usted perdio dos periodos o menos debe realizar unicamente la recuperacion de estos periodos.
# > 2. Si perdio tres o mas periodos debe realizar la recuperacion total de la materia (los 4 periodos)
# > 3. Las recuperacion se dividen en dos partes un trabajo escrito y un conjunto de ejercicios practicos que debe enviar a la plataforma antes de la fecha establecida.
# >> El trabajo escrito debe estar hecho a mano y en hojas cuadriculadas, no se reciben cuadernos.
# > 4. Tanto el trabajo como el ejercicio deben ser sustentados verbalmente y de manera practica.
# > 5. La nota de la recuperacion sera maximo de 3.5 (Basico en la escala general del colegio)
#
# ## Nivelacion Primer Periodo
# ### Trabajo escrito
# > - Defina los siguientes terminos relacionados con referencias:
# >> - Nota al pie
# >> - Nota al final
# >> - Tabla de contenido
# >> - Indice
# >> - Referencias cruzadas
# >> - Rotulo
# > - Explique el procedimiento para:
# >> - Crear un estilo en word
# >> - Crear una tabla de contenido
# >> - Agregar una fuente bibliografica
# >> - Citar un autor en word
# >> - Crear una tabla de contenido
# >> - Insertar numero de pagina a un documento
# >> - Crear un nuevo rotulo
# > Explique que es una tabla de ilustraciones
# > Explique cual es la utilidad de las referencias cruzadas
# ### Ejercicios
# > 1. Dirijase al siguiente enlace [constitucion politica](http://www.secretariasenado.gov.co/senado/basedoc/constitucion_politica_1991.html)
# > 2. Seleccione 10 articulos que usted desee y copielos en un mismo documento de word, teniendo en cuenta que cada articulo debe quedar en una pagina aparte.
# > 3. Para cada articulo busque una imagen que se relacione e insertela en la misma pagina.
# > 4. En la ultima pagina escriba una conclusion de al menos 5 renglones sobre los 10 articulos que selecciono, dentro de este parrafo debe hacer uso de una referencia cruzada que enlace a alguno de los articulos.
# > 5. Al menos tres articulos deben tener una nota al pie que sirva de aclaracion y contextualizacion del mismo.
# > 6. Agregue a dos articulos diferentes a los del punto anterior una referencia bibliografica.
# > 7. Inserte en la primera pagina:
# >> a) tabla de contenido <br>
# >> b) Tabla de imagenes
# > 8. Inserte en la ultima pagina la bibliografia
# > 9. Guarde su documento con el siguiente formato: <br>
# > Apellido_Curso_P1

# %% [markdown]
# ## Nivelacion Segundo Periodo
# ### Trabajo Escrito
# > Explique el procedimiento en Excel para:
# >> - Crear la tabla de valores de una funcion lineal
# >> - Graficar una funcion lineal
# >
# > Sobre los graficos de dispersion XY indique:
# >> - Que son
# >> - Para que tipos de datos se pueden utilizar
# >> - Que muestran
# >
# > Sobre las regresiones lineales explique:
# >> - Que son
# >> - Que usos tienen
# >> - Cual es su importancia
# >
# > Defina los siguientes conceptos relacionados con regresione lineales:
# >> - Linea de tendencia
# >> - Ecuacion de regresion
# >> - Coeficiente de determinacion y su interpretacion
# >> - Coeficiente de correlacion y su interpretacion
# >
# > Indique en que casos es conveniente realizar un pronostico en un modelo de regresion lineal.
# > Nombre tres casos del mundo real donde usted considere util hacer un modelo de pronostico con base en la regresion lineal.
# ### Ejercicios
# > En la Hoja 1 de un libro de Excel, Realice la grafica y la tabla de valores de las siguientes ecuaciones lineales:
# > 1. $ y = 3x + 5 $
# > 2. $ y = 10 - 2x $
# > 3. $ y = 6 - 5x $
# > 4. $ y = 2 - \frac{3x}{5} $
# > 5. $ y = \frac{3}{7} - 5x $
# > En la hoja 2 resuelva el siguiente problema de un modelo de regresion
# > Juan vive cerca de la cuenca alta del rio Fucha en la ciudad de Bogotá, ha notado como el nivel del caudal del rio ha venido en aumento debido a las fuertes lluvias que han caído en la ciudad durante el mes de abril, cerca de su casa, hay un indicador de altura de caudal, que Juan ha venido revisando a diario (con excepción de dos días) y de acuerdo a sus observaciones ha obtenido los siguientes resultados:
# > ![tabla.PNG](attachment:tabla.PNG)
# > Si las lluvias siguen a ese ritmo a Juan le preocupa que el caudal llegue al punto de desbordamiento el cual se ha fijado en 135 cms.
# >
# >Determine
# >1.	La línea de tendencia de los datos
# >2.	La ecuación de regresión lineal y el coeficiente de determinación R2
# >3.	El coeficiente de correlación de Pearson (R)
# >4.	Analiza si es posible establecer un pronóstico de datos futuros.
# >5.	Si es posible realizar el pronóstico, agrega la fórmula de la ecuación de regresión y halla los datos futuros.
# >6.	¿De continuar con el ritmo de lluvias en que día se alcanzaría al nivel de desbordamiento?

# %% [markdown]
# ## Nivelacion tercer periodo
# ### Trabajo escrito
# Lea con detenimiento los Jupyter Notebook del periodo, después de esto,conteste las siguientes preguntas
# >
# >¿Cuál es el significado de la frase "JavaScript es un lenguaje del lado del cliente o del usuario"?.
# >
# >¿Qué función cumplen los diferentes comandos de JavaScript?, por ejemplo: console.log, prompt, document.getElementById().innerHTML, etc.
# >
# >¿Qué es una variable, cómo se definen en JavaScript?
# >
# >¿Cómo se define una función en JavaScript, cuáles son sus partes, que son los parámetros en una función, cómo se invoca?
# >
# >¿Por qué se recomienda usar las funciones como valores de variables?
# >
# >¿Cuál es la ventaja de usar funciones?
# >
# >Nombrar y diferenciar los tipos de operadores de JavaScript: aritméticos, comparación, asignación y lógicos.
# >
# >Conocer y justificar el uso de los operadores (==) y (=), saber en qué casos usar uno u otro.
# >
# >¿Qué son los eventos en JavaScript?
# ### Ejercicio 1
# Realice en un bloc de notas la siguiente pagina web
# > #### Diseño de la página
# >
# > - Título de la página: Ejercicio Tipo 1 (0.5)
# > - Título de contenido en H1: JavaScript para cambiar la apariencia (0.5)
# > - Aplique un color de fondo hexadecimal (0.5)
# > - Busque en internet un párrafo sobre un tema que le llame la atención, este texto debe tener __color diferente__. Escríbalo dentro de las etiquetas correspondientes, como se indica a continuación, no olvide asingarle un id: (0.5)

# %%
# %%html
# <p id="---"> acá va el texto </p>

# %% [markdown]
# > - Después escriba centrado y en otro color su nombre completo (0.5)
# >
# > #### Funcionamiento del Script
# >
# > El script debe accionarse al hacer clic en cualquier parte del párrafo que buscó, inmediatamente el texto será reemplazado por el mensaje: "Esto es JavaScript y es Genial!"
# >
# > Para lograrlo usted debe:
# > - Usar el evento apropiado dentro de la etiqueta < p >, llamando una función diseñada por usted (1.0)
# > - Definir correctamente dentro del script la función correspondiente (1.0)
# > - Escribir correctamente dentro de la función la sentencia que permite reemplazar el texto (1.0)
# >
# > __Condición: este script no debe tener ningún botón para funcionar. En el Jupyter Sesion 3 - parte 2. Se trató este tema.__
# >
# > Guarde su archivo con el nombre:
# > Apellido_Curso_3p_Ejercicio1.HTML

# %% [markdown]
# ### Ejercicio 2
# Realice en un bloc de notas la siguiente pagina web
# >#### Diseño de la página
# > - Título de la página: Ejercicio Tipo 5 (0.5)
# > - Título de contenido en H1: JavaScript para comprobar fechas(0.5)
# > - Aplique un color de fondo hexadecimal (0.5)
# > - Agregue un botón, que contenga el texto: "Pruebe que es un humano", con su respectivo id y evento el cual debe llamar a una función en el script(0.5)
# >
# > #### Funcionamiento del Script
# >
# > Al presionar el botón deben aparecer dos cajas de texto, en la primera se le solicita el año actual, y en la segunda el mes en número. Si el usuario contesta adecuadamente: 2019 y 9 debe mostrar en una ventana emergente el mensaje: "Prueba correcta". En caso de ingresar mal alguno de los dos datos muestra el mensaje: "No es correcto estamos en el año 2019, mes 9". __Importante: En este ultimo mensaje, tanto 2019 y 9 deben ser tomados del metodo Date y no estar escritos directamente__.
# >
# > Para esto debe:
# > - Definir correctamente dentro del script la función correspondiente (0.5)
# > - Definir correctamente dentro de la función las dos variables que necesita (una para el año, otra para el mes) y usar la sentencia para pedir estos datos al usuario. (0.5)
# > - Definir correctamente los objetos de la clase Date encargados de obtener internamente el año y el mes (0.5)
# > - Definir corectamente la estructura condicional (0.5)
# > - Mostrar correctamente el mensaje cuando la condición se cumple (0.5)
# > - Mostrar correctamente el mensaje cuando la condición no se cumple (0.5)
# >
# > > Apellido_Curso_3p_Ejercicio2.HTML

# %% [markdown]
# ## Nivelacion cuarto periodo
# ### Trabajo escrito
# >
# >1. Explique qué es DOM (Document Object Model)
# >2. Realice en su cuaderno (no fotocopia, no impresión) el árbol de objetos DOM de HTML
# >3. Indique cuales acciones o modificaciones se pueden realizar con la manipulación de DOM
# >4. Nombre que elementos se definen através del sistema DOM
# >5. Nombre tres métodos para realizar busqueda de objetos HTML a través de DOM en JavaScript
# >6. Defina que son las propiedades de un objeto en JavaScript
# >7.Explique como se definen las propiedades de una objeto en JavaScript
# >8.Escriba la sintaxis de los objetos de JavaScript para (cite ejemplos):
# >>a) Acceder a una propiedad<br>
# >>b) Agregar nuevas propiedades<br>
# >>c) Eliminar propiedades<br>
# >4. Enuncie Que elementos son considerados objetos en JavaScript
# >5. Sobre el modelo DOM de JavaScript nombre los metodos usados para:
# >>a) Cambiar elementos en documentos HTML <br>
# >>b) Agregar elementos en documentos HTML <br>
# >>c) Eliminar elementos en documentos HTML <br>
# >>d) Nombre la menos 5 metodos usados para encontrar objetos HTML por medio de JavaScript <br>
#
# ### Ejercicio
# > realice en el bloc de notas una pagina web que trate de un tema de su eleccion, la cual debe tener las siguientes caracteristicas:
# >
# > a) Titulo H1 centrado con el nombre del tema
# >
# > b) Al menos dos parrafos acompañados con imagenes
# >
# > c) Una interaccion que use botones para generar un evento : ventana emergente, cambio del texto de un parrafo, agregar informacion, etc.
# >
# > d) Un boton que haga uso del metodo Date que sirva para mostrar la fecha
# >
# > e) Una prueba de captcha que pregunte el año generado con el metodo date y permita permanecer en la pagina si es escrito correctamente o cierre la ventana en caso contrario.
# > Guarde su archivo con el nombre:
# >
# >Apellido_curso_4p_.html
