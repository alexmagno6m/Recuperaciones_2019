# %% [markdown]
# <h1>Indice<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Recuperacion-General-de-Informatica---Grado-10" data-toc-modified-id="Recuperacion-General-de-Informatica---Grado-10-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Recuperacion General de Informatica - Grado 10</a></span><ul class="toc-item"><li><span><a href="#Instrucciones" data-toc-modified-id="Instrucciones-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Instrucciones</a></span></li><li><span><a href="#Nivelacion-Primer-Periodo" data-toc-modified-id="Nivelacion-Primer-Periodo-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Nivelacion Primer Periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-escrito" data-toc-modified-id="Trabajo-escrito-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Trabajo escrito</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Ejercicios</a></span><ul class="toc-item"><li><span><a href="#Ejercicio-1" data-toc-modified-id="Ejercicio-1-1.2.2.1"><span class="toc-item-num">1.2.2.1&nbsp;&nbsp;</span>Ejercicio 1</a></span></li><li><span><a href="#Ejercicio-2" data-toc-modified-id="Ejercicio-2-1.2.2.2"><span class="toc-item-num">1.2.2.2&nbsp;&nbsp;</span>Ejercicio 2</a></span></li></ul></li></ul></li><li><span><a href="#Nivelacion-Segundo-Periodo" data-toc-modified-id="Nivelacion-Segundo-Periodo-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Nivelacion Segundo Periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-Escrito" data-toc-modified-id="Trabajo-Escrito-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Trabajo Escrito</a></span></li><li><span><a href="#Ejercicio" data-toc-modified-id="Ejercicio-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Ejercicio</a></span></li></ul></li><li><span><a href="#Nivelacion-Tercer-Periodo" data-toc-modified-id="Nivelacion-Tercer-Periodo-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Nivelacion Tercer Periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-Escrito" data-toc-modified-id="Trabajo-Escrito-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Trabajo Escrito</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Ejercicios</a></span></li></ul></li><li><span><a href="#Nivelacion-Cuarto-Periodo" data-toc-modified-id="Nivelacion-Cuarto-Periodo-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Nivelacion Cuarto Periodo</a></span><ul class="toc-item"><li><span><a href="#Trabajo-Escrito" data-toc-modified-id="Trabajo-Escrito-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Trabajo Escrito</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Ejercicios</a></span><ul class="toc-item"><li><span><a href="#Ejercicio-1" data-toc-modified-id="Ejercicio-1-1.5.2.1"><span class="toc-item-num">1.5.2.1&nbsp;&nbsp;</span>Ejercicio 1</a></span></li><li><span><a href="#Ejercicio-2" data-toc-modified-id="Ejercicio-2-1.5.2.2"><span class="toc-item-num">1.5.2.2&nbsp;&nbsp;</span>Ejercicio 2</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Recuperacion General de Informatica - Grado 10
# ## Instrucciones
# > 1. Si usted perdio dos periodos o menos debe realizar unicamente la recuperacion de estos periodos.
# > 2. Si perdio tres o mas periodos debe realizar la recuperacion total de la materia (los 4 periodos)
# > 3. Las recuperacion se dividen en dos partes un trabajo escrito y un conjunto de ejercicios practicos que debe enviar a la plataforma antes de la fecha establecida.
# >> El trabajo escrito debe estar hecho a mano y en hojas cuadriculadas, no se reciben cuadernos.
# > 4. Tanto el trabajo como el ejercicio deben ser sustentados verbalmente y de manera practica.
# > 5. La nota de la recuperacion sera maximo de 3.5 (Basico en la escala general del colegio)
#
# __Fecha maxima de envio ejercicios a la plataforma: miercoles 13 hasta las 11.59 PM__
#
# __Fecha de sustentaciones jueves: 14 a las 11.00 AM__

# %% [markdown]
# ## Nivelacion Primer Periodo
# ### Trabajo escrito
# > Sobre las siguientes funciones de Excel: __a) Definalas, b) Escriba la sintaxis (identifique sus partes de ser necesario), c) Escriba un ejemplo__
# >> - Promedio
# >> - Promedio.si
# >> - Suma
# >> - Suma.si
# >> - Desviacion estandar
# >> - Contar.si
# >>
# > Sobre la funcion __si__ investigue:
# >> - Definicion
# >> - Usos
# >> - Sintaxis: nombre sus partes
# >> - Aplicaciones en la vida real
# >> - Escriba la sintaxis de la funcion si anidada
# >> - Indique porque es necesario anidar funciones si
# >>
# > Sobre las funciones __y,__  __o,__ indique:
# >> - Definicion
# >> - Sintaxis
# >> - Explque por que estas dos funciones se usan en conjunto con la funcion __si__.
# >> - Indique en cuales casos usar la funcion __y,__ y en cuales la funcion __o,__ cite dos ejemplos de su uso
# >>
# > Haga una tabla con los operadores de comparacion (o relacionales) que admite Excel
# ### Ejercicios
# > Descargue los archivos con las instrucciones de cada ejercicio, subalos a la plataforma con el nombre que se indica:
# > #### Ejercicio 1
# >> [Archivo Ejercicio 1](ejercicio1.doc)
# >>
# >> Guardelo como:
# >>
# >> apellido_ej1_P1
# >>
# > #### Ejercicio 2
# >> [Archivo Ejercicio 2](ejercicio2.docx)
# >>
# >> Guardelo como:
# >>
# >> apellido_ej2_P1

# %% [markdown]
# ## Nivelacion Segundo Periodo
# ### Trabajo Escrito
# > Sobre el formato condicional, investigue:
# >> - Concepto
# >> - Como funciona
# >> - Cuales son sus usos
# >> - Nombre tres casos de la vida cotidiana donde el formato concidional puede ser util.
# >>
# > Indique el procedimiento para aplicar formato concidional mediante una formula propia.
# >
# > Defina las siguientes herramientas asociadas a formato condicional:
# >> - Reglas para resaltar celdas
# >> - Reglas para valores superiores e inferiores
# >> - Barra de datos
# >> - Escalas de color
# >> - Conjunto de iconos
# >> - Nueva regla
# >> - Borrar regla
# >> - Administrar reglas
# >>
# > Indique la funcion de TODAS las opciones y comandos que aparecen en la siguiente ventana (haga el dibujo):
# >> ![formato.PNG](attachment:formato.PNG)
# ### Ejercicio
# > Descargue el archivo con las instrucciones de cada ejercicio, subalo a la plataforma con el nombre que se indica:
# >>
# >>[Archivo Ejercicio](ejercicio2P.docx)
# >>
# >> Guardelo como:
# >>
# >> apellido_ej1_P2

# %% [markdown]
# ## Nivelacion Tercer Periodo
# ### Trabajo Escrito
# > Sobre Microsoft Access investigue:
# >> - Que es
# >> - Cuales son sus caracteristicas
# >> - Nombre al menos 5 ventajas
# >> - Que usos tiene
# >
# > Sobre las bases de datos investigue:
# >> - Que son
# >> - Como funcionan
# >> - Cual es su estructura
# >> - Indique su importancia
# >> - Nombre al menos tres casos de la vida real donde se usen bases de datos, justifique su respuesta
# >
# > Defina los siguientes conceptos asociados a bases de datos
# >> - Tabla
# >> - Campos
# >> - Tipos de campos
# >> - Explique el procedimiento para crear una tabla en Access
# >
# > Sobre los forumlarios investigue:
# >> - Que son
# >> - Cual es su funcion
# >> - Que usus tiene
# >> - Explique el procedimiento para crear un formulario en Access a traves del asistente para formularios
# >
# > Sobre el modelo de bases de datos relacionales, investigue:
# >> - Que es
# >> - Cuales son sus caracteristivas
# >> - Que ventajas tiene
# >> - Explique el procedimiento para crear relaciones entre tablas en Access
# ### Ejercicios
# > A continuacion encontrara el enlace para descargar los ejercicios, __debe realizar los tres ejericios propuestos y guardarlos en archivos independientes con el nombre que se indica en las instrucciones y subirlo a la plataforma__
# >>
# >> [Archivo Ejercicio](ejercicio3P.docx)

# %% [markdown]
# ## Nivelacion Cuarto Periodo
# ### Trabajo Escrito
# > Sobre el lenguaje HTML investigue:
# >> - Que es
# >> - Historia
# >> - Caracteristicas
# >> - Usos
# >>
# > Indique que es una pagina web y describa su funcionamiento basico
# >
# > Explique la estructura basica de una pagina web sencilla
# >
# > Enuncie la funcion de las siguientes etiquetas
# >> - B
# >> - I
# >> - S
# >> - Center
# >> - Head
# >> - Title
# >> - cabeceras H1, H2, H3
# >> - hr
# >> - br
# >> - p
# >> - strong
# >> - font
# >
# > Explique como se crea una lista ordenada, enuncie la sintaxis
# >
# > Explique como se crea una lista sin ordenar, enuncie la sintaxis
# >
# > Sobre las tablas en HTML investigue:
# >> - Como se crean
# >> - Que usos tienen
# >> - Como se aplica color a una fila y a una celda
# >>
# > Escriba la sintaxis y un ejemplo sobre:
# >> - Enlaces a una pagina que se abra en la misma ventana
# >> - Enlaces a una pagina que se abra en una nueva ventana
# >> - Enlaces a correo electronicos
# >> - Insertar una imagen
# >> - Enlaces a un archivo
# ### Ejercicios
# > Descargue los archivos con las instrucciones de cada ejercicio, subalos a la plataforma con el nombre que se indica:
# >
# > #### Ejercicio 1
# >> [Archivo Ejercicio 1](ejercicio4P_1.docx)
# >>
# >> Guardelo como:
# >>
# >> apellido_ej1_P4
# >>
# > #### Ejercicio 2
# >> [Archivo Ejercicio 2](ejercicio4P_2.docx)
# >>
# >> Guardelo como:
# >>
# >> apellido_ej2_P4
