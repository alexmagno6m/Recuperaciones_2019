# %% [markdown]
# # Recuperacion General de Programacion - Grado 1001
# ## Instrucciones
# > 1. Si usted perdio dos periodos o menos debe realizar unicamente la recuperacion de estos periodos.
# > 2. Si perdio tres o mas periodos debe realizar la recuperacion total de la materia (los 4 periodos)
# > 3. Las recuperacion consiste en un trabajo escrito y un conjunto de ejercicios practicos que se le entregaran el dia que sustente el trabajo escrito.
# >> El trabajo escrito debe estar hecho a mano y en hojas cuadriculadas, no se reciben cuadernos.
# > 4. Tanto el trabajo como el ejercicio deben ser sustentados verbalmente y de manera practica.
# > 5. La nota de la recuperacion sera maximo de 3.5 (Basico en la escala general del colegio)
#
#
# __Fecha de sustentaciones jueves: 14 a la 1:00PM__

# %% [markdown]
# ## Nivelacion Primer Periodo
# > Defina los siguientes conceptos
# >> - Programa
# >> - Programar
# >> - Lenguaje de programacion
# >> - Programador
# >> - Codigo
# >> - Pseudocodigo
# >
# > Sobre los algoritmos investigue:
# >> - Que son
# >> - Cuales son sus caracteristicas
# >> - Como se clasifican
# >
# > Sobre los tipos de datos defina:
# >> - Cadenas
# >> - Numeros
# >> - Booleanos
# >
# > Realice una tabla con los siguientes operadores:
# >> - Relacionales
# >> - Aritmeticos
# >> - Logicos
# >> - Booleanos
# >
# > Realice la tabla de la verdad de los operadores __and__ y __or__
# >
# > Sobre los diagramas de flujo investigue:
# >> - Que son
# >> - Cuales son sus caracteristicas
# >> - Como se realizan
# >> - Que usos tienen
# >
# ## Nivelacion Segundo Periodo
# >
# > Sobre PSeInt investigue:
# >> - Que es
# >> - Cual es su funcion
# >> - Sus caracteristicas
# >> - Sus ventajas
# >>
# > Sobre las estructuras condicionales indique:
# >> - Que son
# >> - Que usos tienen
# >> - Sintaxis en PSeInt
# >
# > Sobre los ciclos, loops o bucles investigue:
# >> - Que son
# >> - Cual es su importancia en programacion
# >> - Que usos tienen
# >
# > Sobre el ciclo a) _mientras (while)_ y b) _para (for)_ investigue:
# >> - Su funcionamiento
# >> - Sintaxis en PSeInt
# >
# > Dibuje las figuras de los diagramas de flujo encargadas de representar:
# >> - Asignacion
# >> - Salida por teclado
# >> - Entrada de datos
# >> - Decision
# >> - Iteracion o bucles

# %% [markdown]
# ## Nivelacion Tercer Periodo
# > Sobre las simulaciones por computador indique:
# >> - Que son
# >> - Sus principales aplicaciones
# >> - Sus ventajas
# >
# > Indique que es un modelo computacional
# >
# > Nombre tres campos de estudio donde se pueden aplicar simulaciones computacionales
# >
# > Nombre tres software de simulacion computacional
# >
# > Sobre Netlogo investigue:
# >> - Que es
# >> - Cuales son sus caracteristicas
# >> - Que aplicaciones tienen
# >
# ## Nivelacion Cuarto Periodo
# >
# > Describa las caracteristicas de los siguientes agentes en Netlogo:
# >> - Turtles
# >> - Links
# >> - Patches
# >> - Observer (observador)
# >
# > Escriba la sintaxis usada en PSeInt para:
# >> - Crear tortugas
# >> - Aplicar color, tamaño
# >> - Posicionar en el escenario las tortugas
# >> - Aplicar color a los patches
# >
# > Explique por que son necesarios los _ticks_ en una simulacion en Netlogo
# >
# > Sobre las razas en Netlogo indique:
# >> Que son
# >> Como se definen, escriba la sintaxis
# >
# > Sobre las formas (shapes) en Netlogo indique:
# >> Cual es su utilidad
# >> Escriba la sintaxis para aplicar una forma a una tortuga.
